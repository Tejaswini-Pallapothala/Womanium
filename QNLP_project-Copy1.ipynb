# %% [markdown]
# # Quantum NLP using the Quantum Trainer

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /opt/conda/lib/python3.9/site-packages (1.4.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/conda/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.9/site-packages (from pandas) (2021.3)
# Requirement already satisfied: numpy>=1.18.5 in /opt/conda/lib/python3.9/site-packages (from pandas) (1.23.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
#
# [notice] A new release of pip available: 22.1.2 -> 22.2.2
# [notice] To update, run: pip install --upgrade pip

# %%
import warnings
warnings.filterwarnings("ignore")

import os
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %%
import numpy as np

BATCH_SIZE = 5
EPOCHS = 6
SEED = 2
len_dataset = 100

# %%
import pandas as pd
df = pd.read_csv('MC1.TXT', header=None)
df.head(2)
# Out:
#                                  0  \
# 0    cook creates complicated dish
# 1  skilful programmer creates code
#
#                                              1  2
# 0   experienced chef prepares complicated dish  1
# 1                   devoted hacker writes code  1

# %%
df.rename(columns = {0:'sentence1', 1:'sentence2', 2:'label'}, inplace = True)

df.to_csv('dataset2.csv', index=None)

# %% [markdown]
# ### Read in the data and create diagrams

# %%
train_split = int(len_dataset * 0.8)
val_split = int(len_dataset * 0.9)
test_split = int(len_dataset)

df = pd.read_csv('dataset2' + '.csv')
df.head()
df_negative = df[df['label'] == 0]
df_positive = df[df['label'] == 1]

df_positive = df_positive[:int(len_dataset * 0.53)]
df_negative = df_negative[:int(len_dataset * 0.47)]

df_final = pd.concat([df_positive, df_negative])

data1 = list(df_final['sentence1'])
data2 = list(df_final['sentence2'])
data = df_final['sentence1'] +' '+ df_final['sentence2']
data =list(data)
labels_raw = list(df_final['label'])

labels = [[x, 1-x] for x in labels_raw]

train_data = data[:train_split]
dev_data = data[train_split:val_split]
test_data = data[val_split:test_split]

train_labels = labels[:train_split]
dev_labels = labels[train_split:val_split]
test_labels = labels[val_split:test_split]

# %% [markdown]
# ### Create diagrams

# %%
# !pip install cirq
# Out:
# Requirement already satisfied: cirq in /opt/conda/lib/python3.9/site-packages (1.0.0)
# Requirement already satisfied: cirq-google==1.0.0 in /opt/conda/lib/python3.9/site-packages (from cirq) (1.0.0)
# Requirement already satisfied: cirq-pasqal==1.0.0 in /opt/conda/lib/python3.9/site-packages (from cirq) (1.0.0)
# Requirement already satisfied: cirq-aqt==1.0.0 in /opt/conda/lib/python3.9/site-packages (from cirq) (1.0.0)
# Requirement already satisfied: cirq-core==1.0.0 in /opt/conda/lib/python3.9/site-packages (from cirq) (1.0.0)
# Requirement already satisfied: cirq-web==1.0.0 in /opt/conda/lib/python3.9/site-packages (from cirq) (1.0.0)
# Requirement already satisfied: cirq-ionq==1.0.0 in /opt/conda/lib/python3.9/site-packages (from cirq) (1.0.0)
# Requirement already satisfied: cirq-rigetti==1.0.0 in /opt/conda/lib/python3.9/site-packages (from cirq) (1.0.0)
# Requirement already satisfied: requests~=2.18 in /opt/conda/lib/python3.9/site-packages (from cirq-aqt==1.0.0->cirq) (2.27.1)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.9/site-packages (from cirq-core==1.0.0->cirq) (1.4.3)
# Requirement already satisfied: numpy~=1.16 in /opt/conda/lib/python3.9/site-packages (from cirq-core==1.0.0->cirq) (1.23.1)
# Requirement already satisfied: networkx~=2.4 in /opt/conda/lib/python3.9/site-packages (from cirq-core==1.0.0->cirq) (2.8.6)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.9/site-packages (from cirq-core==1.0.0->cirq) (4.3.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.9/site-packages (from cirq-core==1.0.0->cirq) (4.62.3)
# Requirement already satisfied: duet~=0.2.7 in /opt/conda/lib/python3.9/site-packages (from cirq-core==1.0.0->cirq) (0.2.7)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.9/site-packages (from cirq-core==1.0.0->cirq) (1.10.1)
# Requirement already satisfied: matplotlib~=3.0 in /opt/conda/lib/python3.9/site-packages (from cirq-core==1.0.0->cirq) (3.5.2)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.9/site-packages (from cirq-core==1.0.0->cirq) (1.8.1)
# Requirement already satisfied: sortedcontainers~=2.0 in /opt/conda/lib/python3.9/site-packages (from cirq-core==1.0.0->cirq) (2.4.0)
# Requirement already satisfied: protobuf<4,>=3.15.0 in /opt/conda/lib/python3.9/site-packages (from cirq-google==1.0.0->cirq) (3.20.1)
# Requirement already satisfied: proto-plus>=1.20.0 in /opt/conda/lib/python3.9/site-packages (from cirq-google==1.0.0->cirq) (1.22.0)
# Requirement already satisfied: google-api-core[grpc]<2.0.0dev,>=1.14.0 in /opt/conda/lib/python3.9/site-packages (from cirq-google==1.0.0->cirq) (1.32.0)
# Requirement already satisfied: pyquil>=3.0.0 in /opt/conda/lib/python3.9/site-packages (from cirq-rigetti==1.0.0->cirq) (3.3.0)
# Requirement already satisfied: setuptools>=40.3.0 in /opt/conda/lib/python3.9/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.14.0->cirq-google==1.0.0->cirq) (60.9.3)
# Requirement already satisfied: pytz in /opt/conda/lib/python3.9/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.14.0->cirq-google==1.0.0->cirq) (2021.3)
# Requirement already satisfied: packaging>=14.3 in /opt/conda/lib/python3.9/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.14.0->cirq-google==1.0.0->cirq) (21.3)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /opt/conda/lib/python3.9/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.14.0->cirq-google==1.0.0->cirq) (1.56.4)
# Requirement already satisfied: six>=1.13.0 in /opt/conda/lib/python3.9/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.14.0->cirq-google==1.0.0->cirq) (1.16.0)
# Requirement already satisfied: google-auth<2.0dev,>=1.25.0 in /opt/conda/lib/python3.9/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.14.0->cirq-google==1.0.0->cirq) (1.35.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.29.0 in /opt/conda/lib/python3.9/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.14.0->cirq-google==1.0.0->cirq) (1.47.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.9/site-packages (from matplotlib~=3.0->cirq-core==1.0.0->cirq) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib~=3.0->cirq-core==1.0.0->cirq) (1.4.3)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.9/site-packages (from matplotlib~=3.0->cirq-core==1.0.0->cirq) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib~=3.0->cirq-core==1.0.0->cirq) (3.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.9/site-packages (from matplotlib~=3.0->cirq-core==1.0.0->cirq) (4.34.4)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.9/site-packages (from matplotlib~=3.0->cirq-core==1.0.0->cirq) (9.2.0)
# Requirement already satisfied: qcs-api-client<0.22.0,>=0.20.13 in /opt/conda/lib/python3.9/site-packages (from pyquil>=3.0.0->cirq-rigetti==1.0.0->cirq) (0.21.1)
# Requirement already satisfied: rpcq<4.0.0,>=3.10.0 in /opt/conda/lib/python3.9/site-packages (from pyquil>=3.0.0->cirq-rigetti==1.0.0->cirq) (3.10.0)
# Requirement already satisfied: retry<0.10.0,>=0.9.2 in /opt/conda/lib/python3.9/site-packages (from pyquil>=3.0.0->cirq-rigetti==1.0.0->cirq) (0.9.2)
# Requirement already satisfied: lark<0.12.0,>=0.11.1 in /opt/conda/lib/python3.9/site-packages (from pyquil>=3.0.0->cirq-rigetti==1.0.0->cirq) (0.11.3)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.9/site-packages (from requests~=2.18->cirq-aqt==1.0.0->cirq) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/conda/lib/python3.9/site-packages (from requests~=2.18->cirq-aqt==1.0.0->cirq) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.9/site-packages (from requests~=2.18->cirq-aqt==1.0.0->cirq) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.9/site-packages (from requests~=2.18->cirq-aqt==1.0.0->cirq) (1.26.8)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.9/site-packages (from sympy->cirq-core==1.0.0->cirq) (1.2.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.9/site-packages (from google-auth<2.0dev,>=1.25.0->google-api-core[grpc]<2.0.0dev,>=1.14.0->cirq-google==1.0.0->cirq) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /opt/conda/lib/python3.9/site-packages (from google-auth<2.0dev,>=1.25.0->google-api-core[grpc]<2.0.0dev,>=1.14.0->cirq-google==1.0.0->cirq) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.9/site-packages (from google-auth<2.0dev,>=1.25.0->google-api-core[grpc]<2.0.0dev,>=1.14.0->cirq-google==1.0.0->cirq) (0.2.8)
# Requirement already satisfied: iso8601<2.0.0,>=1.0.2 in /opt/conda/lib/python3.9/site-packages (from qcs-api-client<0.22.0,>=0.20.13->pyquil>=3.0.0->cirq-rigetti==1.0.0->cirq) (1.0.2)
# Requirement already satisfied: httpx<0.16.0,>=0.15.0 in /opt/conda/lib/python3.9/site-packages (from qcs-api-client<0.22.0,>=0.20.13->pyquil>=3.0.0->cirq-rigetti==1.0.0->cirq) (0.15.5)
# Requirement already satisfied: attrs<21.0.0,>=20.1.0 in /opt/conda/lib/python3.9/site-packages (from qcs-api-client<0.22.0,>=0.20.13->pyquil>=3.0.0->cirq-rigetti==1.0.0->cirq) (20.3.0)
# Requirement already satisfied: rfc3339<7.0,>=6.2 in /opt/conda/lib/python3.9/site-packages (from qcs-api-client<0.22.0,>=0.20.13->pyquil>=3.0.0->cirq-rigetti==1.0.0->cirq) (6.2)
# Requirement already satisfied: toml<0.11.0,>=0.10.2 in /opt/conda/lib/python3.9/site-packages (from qcs-api-client<0.22.0,>=0.20.13->pyquil>=3.0.0->cirq-rigetti==1.0.0->cirq) (0.10.2)
# Requirement already satisfied: pydantic<2.0.0,>=1.7.2 in /opt/conda/lib/python3.9/site-packages (from qcs-api-client<0.22.0,>=0.20.13->pyquil>=3.0.0->cirq-rigetti==1.0.0->cirq) (1.9.2)
# Requirement already satisfied: PyJWT<3.0.0,>=2.4.0 in /opt/conda/lib/python3.9/site-packages (from qcs-api-client<0.22.0,>=0.20.13->pyquil>=3.0.0->cirq-rigetti==1.0.0->cirq) (2.4.0)
# Requirement already satisfied: retrying<2.0.0,>=1.3.3 in /opt/conda/lib/python3.9/site-packages (from qcs-api-client<0.22.0,>=0.20.13->pyquil>=3.0.0->cirq-rigetti==1.0.0->cirq) (1.3.3)
# Requirement already satisfied: decorator>=3.4.2 in /opt/conda/lib/python3.9/site-packages (from retry<0.10.0,>=0.9.2->pyquil>=3.0.0->cirq-rigetti==1.0.0->cirq) (5.1.1)
# Requirement already satisfied: py<2.0.0,>=1.4.26 in /opt/conda/lib/python3.9/site-packages (from retry<0.10.0,>=0.9.2->pyquil>=3.0.0->cirq-rigetti==1.0.0->cirq) (1.11.0)
# Requirement already satisfied: ruamel.yaml in /opt/conda/lib/python3.9/site-packages (from rpcq<4.0.0,>=3.10.0->pyquil>=3.0.0->cirq-rigetti==1.0.0->cirq) (0.17.21)
# Requirement already satisfied: pyzmq>=17 in /opt/conda/lib/python3.9/site-packages (from rpcq<4.0.0,>=3.10.0->pyquil>=3.0.0->cirq-rigetti==1.0.0->cirq) (19.0.2)
# Requirement already satisfied: python-rapidjson in /opt/conda/lib/python3.9/site-packages (from rpcq<4.0.0,>=3.10.0->pyquil>=3.0.0->cirq-rigetti==1.0.0->cirq) (1.8)
# Requirement already satisfied: msgpack<1.0,>=0.6 in /opt/conda/lib/python3.9/site-packages (from rpcq<4.0.0,>=3.10.0->pyquil>=3.0.0->cirq-rigetti==1.0.0->cirq) (0.6.2)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.9/site-packages (from httpx<0.16.0,>=0.15.0->qcs-api-client<0.22.0,>=0.20.13->pyquil>=3.0.0->cirq-rigetti==1.0.0->cirq) (1.2.0)
# Requirement already satisfied: rfc3986[idna2008]<2,>=1.3 in /opt/conda/lib/python3.9/site-packages (from httpx<0.16.0,>=0.15.0->qcs-api-client<0.22.0,>=0.20.13->pyquil>=3.0.0->cirq-rigetti==1.0.0->cirq) (1.5.0)
# Requirement already satisfied: httpcore==0.11.* in /opt/conda/lib/python3.9/site-packages (from httpx<0.16.0,>=0.15.0->qcs-api-client<0.22.0,>=0.20.13->pyquil>=3.0.0->cirq-rigetti==1.0.0->cirq) (0.11.1)
# Requirement already satisfied: h11<0.10,>=0.8 in /opt/conda/lib/python3.9/site-packages (from httpcore==0.11.*->httpx<0.16.0,>=0.15.0->qcs-api-client<0.22.0,>=0.20.13->pyquil>=3.0.0->cirq-rigetti==1.0.0->cirq) (0.9.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/conda/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<2.0dev,>=1.25.0->google-api-core[grpc]<2.0.0dev,>=1.14.0->cirq-google==1.0.0->cirq) (0.4.8)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.6 in /opt/conda/lib/python3.9/site-packages (from ruamel.yaml->rpcq<4.0.0,>=3.10.0->pyquil>=3.0.0->cirq-rigetti==1.0.0->cirq) (0.2.6)
#
# [notice] A new release of pip available: 22.1.2 -> 22.2.2
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install lambeq
# Out:
# Requirement already satisfied: lambeq in /opt/conda/lib/python3.9/site-packages (0.2.6)
# Requirement already satisfied: transformers in /opt/conda/lib/python3.9/site-packages (from lambeq) (4.21.1)
# Requirement already satisfied: spacy>=3.0 in /opt/conda/lib/python3.9/site-packages (from lambeq) (3.4.1)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.9/site-packages (from lambeq) (5.4.1)
# Requirement already satisfied: tensornetwork in /opt/conda/lib/python3.9/site-packages (from lambeq) (0.4.6)
# Requirement already satisfied: torch>=1.10.1 in /opt/conda/lib/python3.9/site-packages (from lambeq) (1.12.1)
# Requirement already satisfied: discopy>=0.4.2 in /opt/conda/lib/python3.9/site-packages (from lambeq) (0.4.2)
# Requirement already satisfied: pytket>=0.19.2 in /opt/conda/lib/python3.9/site-packages (from lambeq) (1.5.1.1)
# Requirement already satisfied: matplotlib>=3.1.2 in /opt/conda/lib/python3.9/site-packages (from discopy>=0.4.2->lambeq) (3.5.2)
# Requirement already satisfied: pillow>=6.2.1 in /opt/conda/lib/python3.9/site-packages (from discopy>=0.4.2->lambeq) (9.2.0)
# Requirement already satisfied: networkx>=2.4 in /opt/conda/lib/python3.9/site-packages (from discopy>=0.4.2->lambeq) (2.8.6)
# Requirement already satisfied: numpy>=1.18.1 in /opt/conda/lib/python3.9/site-packages (from discopy>=0.4.2->lambeq) (1.23.1)
# Requirement already satisfied: lark-parser~=0.7 in /opt/conda/lib/python3.9/site-packages (from pytket>=0.19.2->lambeq) (0.12.0)
# Requirement already satisfied: types-pkg-resources in /opt/conda/lib/python3.9/site-packages (from pytket>=0.19.2->lambeq) (0.1.3)
# Requirement already satisfied: jinja2~=3.0 in /opt/conda/lib/python3.9/site-packages (from pytket>=0.19.2->lambeq) (3.0.3)
# Requirement already satisfied: typing-extensions~=4.2 in /opt/conda/lib/python3.9/site-packages (from pytket>=0.19.2->lambeq) (4.3.0)
# Requirement already satisfied: sympy~=1.6 in /opt/conda/lib/python3.9/site-packages (from pytket>=0.19.2->lambeq) (1.10.1)
# Requirement already satisfied: scipy<2.0,>=1.7.2 in /opt/conda/lib/python3.9/site-packages (from pytket>=0.19.2->lambeq) (1.8.1)
# Requirement already satisfied: graphviz~=0.14 in /opt/conda/lib/python3.9/site-packages (from pytket>=0.19.2->lambeq) (0.20.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/conda/lib/python3.9/site-packages (from spacy>=3.0->lambeq) (1.0.8)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/conda/lib/python3.9/site-packages (from spacy>=3.0->lambeq) (4.62.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /opt/conda/lib/python3.9/site-packages (from spacy>=3.0->lambeq) (2.0.8)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /opt/conda/lib/python3.9/site-packages (from spacy>=3.0->lambeq) (1.0.3)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /opt/conda/lib/python3.9/site-packages (from spacy>=3.0->lambeq) (8.1.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /opt/conda/lib/python3.9/site-packages (from spacy>=3.0->lambeq) (3.3.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.10.0,>=1.7.4 in /opt/conda/lib/python3.9/site-packages (from spacy>=3.0->lambeq) (1.9.2)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.9/site-packages (from spacy>=3.0->lambeq) (21.3)
# Requirement already satisfied: pathy>=0.3.5 in /opt/conda/lib/python3.9/site-packages (from spacy>=3.0->lambeq) (0.6.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in /opt/conda/lib/python3.9/site-packages (from spacy>=3.0->lambeq) (3.0.10)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /opt/conda/lib/python3.9/site-packages (from spacy>=3.0->lambeq) (2.4.4)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/conda/lib/python3.9/site-packages (from spacy>=3.0->lambeq) (2.0.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/conda/lib/python3.9/site-packages (from spacy>=3.0->lambeq) (2.27.1)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /opt/conda/lib/python3.9/site-packages (from spacy>=3.0->lambeq) (0.4.2)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.9/site-packages (from spacy>=3.0->lambeq) (60.9.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /opt/conda/lib/python3.9/site-packages (from spacy>=3.0->lambeq) (0.10.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/conda/lib/python3.9/site-packages (from spacy>=3.0->lambeq) (3.0.7)
# Requirement already satisfied: h5py>=2.9.0 in /opt/conda/lib/python3.9/site-packages (from tensornetwork->lambeq) (3.7.0)
# Requirement already satisfied: opt-einsum>=2.3.0 in /opt/conda/lib/python3.9/site-packages (from tensornetwork->lambeq) (3.3.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /opt/conda/lib/python3.9/site-packages (from transformers->lambeq) (0.12.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.9/site-packages (from transformers->lambeq) (2022.8.17)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /opt/conda/lib/python3.9/site-packages (from transformers->lambeq) (0.8.1)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.9/site-packages (from transformers->lambeq) (3.8.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.9/site-packages (from jinja2~=3.0->pytket>=0.19.2->lambeq) (2.1.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib>=3.1.2->discopy>=0.4.2->lambeq) (3.0.7)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.9/site-packages (from matplotlib>=3.1.2->discopy>=0.4.2->lambeq) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.9/site-packages (from matplotlib>=3.1.2->discopy>=0.4.2->lambeq) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.9/site-packages (from matplotlib>=3.1.2->discopy>=0.4.2->lambeq) (4.34.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib>=3.1.2->discopy>=0.4.2->lambeq) (1.4.3)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in /opt/conda/lib/python3.9/site-packages (from pathy>=0.3.5->spacy>=3.0->lambeq) (5.2.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/conda/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0->lambeq) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0->lambeq) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0->lambeq) (1.26.8)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0->lambeq) (3.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.9/site-packages (from sympy~=1.6->pytket>=0.19.2->lambeq) (1.2.1)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /opt/conda/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.0->spacy>=3.0->lambeq) (0.7.8)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /opt/conda/lib/python3.9/site-packages (from typer<0.5.0,>=0.3.0->spacy>=3.0->lambeq) (8.1.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.1.2->discopy>=0.4.2->lambeq) (1.16.0)
#
# [notice] A new release of pip available: 22.1.2 -> 22.2.2
# [notice] To update, run: pip install --upgrade pip

# %%
from lambeq import BobcatParser

# %%
parser = BobcatParser(verbose='text')

raw_train_diagrams = parser.sentences2diagrams(train_data)
raw_dev_diagrams = parser.sentences2diagrams(dev_data)
raw_test_diagrams = parser.sentences2diagrams(test_data)
# Out:
# Tagging sentences.
# Parsing tagged sentences.
# Turning parse trees to diagrams.
# Tagging sentences.
# Parsing tagged sentences.
# Turning parse trees to diagrams.
# Tagging sentences.
# Parsing tagged sentences.
# Turning parse trees to diagrams.

# %% [markdown]
# ### Remove the cups

# %%
from lambeq import remove_cups

train_diagrams = [remove_cups(diagram) for diagram in raw_train_diagrams]
dev_diagrams = [remove_cups(diagram) for diagram in raw_dev_diagrams]
test_diagrams = [remove_cups(diagram) for diagram in raw_test_diagrams]

train_diagrams[0].draw()

# %%
from lambeq import remove_cups

train_diagrams = [remove_cups(diagram) for diagram in raw_train_diagrams]
dev_diagrams = [remove_cups(diagram) for diagram in raw_dev_diagrams]
test_diagrams = [remove_cups(diagram) for diagram in raw_test_diagrams]

train_diagrams[1].draw()

# %%
from discopy import Dim

from lambeq import AtomicType, SpiderAnsatz

ansatz = SpiderAnsatz({AtomicType.NOUN: Dim(2),
                       AtomicType.SENTENCE: Dim(2)})

train_circuits = [ansatz(diagram) for diagram in train_diagrams]
dev_circuits =  [ansatz(diagram) for diagram in dev_diagrams]
test_circuits = [ansatz(diagram) for diagram in test_diagrams]

train_circuits[0].draw()

# %%
from discopy import Dim

from lambeq import AtomicType, SpiderAnsatz

ansatz = SpiderAnsatz({AtomicType.NOUN: Dim(2),
                       AtomicType.SENTENCE: Dim(2)})

train_circuits = [ansatz(diagram) for diagram in train_diagrams]
dev_circuits =  [ansatz(diagram) for diagram in dev_diagrams]
test_circuits = [ansatz(diagram) for diagram in test_diagrams]

train_circuits[1].draw()

# %% [markdown]
# ### Create circuits

# %%
from lambeq import AtomicType, IQPAnsatz

ansatz = IQPAnsatz({AtomicType.NOUN: 1, AtomicType.SENTENCE: 1},
                   n_layers=1, n_single_qubit_params=3)

train_circuits = [ansatz(diagram) for diagram in train_diagrams]
dev_circuits =  [ansatz(diagram) for diagram in dev_diagrams]
test_circuits = [ansatz(diagram) for diagram in test_diagrams]

train_circuits[0].draw(figsize=(9, 12))

# %%
from lambeq import AtomicType, IQPAnsatz

ansatz = IQPAnsatz({AtomicType.NOUN: 1, AtomicType.SENTENCE: 1},
                   n_layers=1, n_single_qubit_params=3)

train_circuits = [ansatz(diagram) for diagram in train_diagrams]
dev_circuits =  [ansatz(diagram) for diagram in dev_diagrams]
test_circuits = [ansatz(diagram) for diagram in test_diagrams]

train_circuits[1].draw(figsize=(9, 12))

# %%
# !pip install pytket-qiskit
# Out:
# Requirement already satisfied: pytket-qiskit in /opt/conda/lib/python3.9/site-packages (0.28.0)
# Requirement already satisfied: pytket~=1.5 in /opt/conda/lib/python3.9/site-packages (from pytket-qiskit) (1.5.1.1)
# Requirement already satisfied: qiskit~=0.37.0 in /opt/conda/lib/python3.9/site-packages (from pytket-qiskit) (0.37.1)
# Requirement already satisfied: scipy<2.0,>=1.7.2 in /opt/conda/lib/python3.9/site-packages (from pytket~=1.5->pytket-qiskit) (1.8.1)
# Requirement already satisfied: graphviz~=0.14 in /opt/conda/lib/python3.9/site-packages (from pytket~=1.5->pytket-qiskit) (0.20.1)
# Requirement already satisfied: numpy<2.0,>=1.21.4 in /opt/conda/lib/python3.9/site-packages (from pytket~=1.5->pytket-qiskit) (1.23.1)
# Requirement already satisfied: jinja2~=3.0 in /opt/conda/lib/python3.9/site-packages (from pytket~=1.5->pytket-qiskit) (3.0.3)
# Requirement already satisfied: types-pkg-resources in /opt/conda/lib/python3.9/site-packages (from pytket~=1.5->pytket-qiskit) (0.1.3)
# Requirement already satisfied: typing-extensions~=4.2 in /opt/conda/lib/python3.9/site-packages (from pytket~=1.5->pytket-qiskit) (4.3.0)
# Requirement already satisfied: lark-parser~=0.7 in /opt/conda/lib/python3.9/site-packages (from pytket~=1.5->pytket-qiskit) (0.12.0)
# Requirement already satisfied: networkx~=2.4 in /opt/conda/lib/python3.9/site-packages (from pytket~=1.5->pytket-qiskit) (2.8.6)
# Requirement already satisfied: sympy~=1.6 in /opt/conda/lib/python3.9/site-packages (from pytket~=1.5->pytket-qiskit) (1.10.1)
# Requirement already satisfied: qiskit-terra==0.21.1 in /opt/conda/lib/python3.9/site-packages (from qiskit~=0.37.0->pytket-qiskit) (0.21.1)
# Requirement already satisfied: qiskit-aer==0.10.4 in /opt/conda/lib/python3.9/site-packages (from qiskit~=0.37.0->pytket-qiskit) (0.10.4)
# Requirement already satisfied: qiskit-ibmq-provider==0.19.2 in /opt/conda/lib/python3.9/site-packages (from qiskit~=0.37.0->pytket-qiskit) (0.19.2)
# Requirement already satisfied: requests-ntlm>=1.1.0 in /opt/conda/lib/python3.9/site-packages (from qiskit-ibmq-provider==0.19.2->qiskit~=0.37.0->pytket-qiskit) (1.1.0)
# Requirement already satisfied: websocket-client>=1.0.1 in /opt/conda/lib/python3.9/site-packages (from qiskit-ibmq-provider==0.19.2->qiskit~=0.37.0->pytket-qiskit) (1.3.1)
# Requirement already satisfied: requests>=2.19 in /opt/conda/lib/python3.9/site-packages (from qiskit-ibmq-provider==0.19.2->qiskit~=0.37.0->pytket-qiskit) (2.27.1)
# Requirement already satisfied: python-dateutil>=2.8.0 in /opt/conda/lib/python3.9/site-packages (from qiskit-ibmq-provider==0.19.2->qiskit~=0.37.0->pytket-qiskit) (2.8.2)
# Requirement already satisfied: urllib3>=1.21.1 in /opt/conda/lib/python3.9/site-packages (from qiskit-ibmq-provider==0.19.2->qiskit~=0.37.0->pytket-qiskit) (1.26.8)
# Requirement already satisfied: websockets>=10.0 in /opt/conda/lib/python3.9/site-packages (from qiskit-ibmq-provider==0.19.2->qiskit~=0.37.0->pytket-qiskit) (10.3)
# Requirement already satisfied: psutil>=5 in /opt/conda/lib/python3.9/site-packages (from qiskit-terra==0.21.1->qiskit~=0.37.0->pytket-qiskit) (5.9.0)
# Requirement already satisfied: tweedledum<2.0,>=1.1 in /opt/conda/lib/python3.9/site-packages (from qiskit-terra==0.21.1->qiskit~=0.37.0->pytket-qiskit) (1.1.1)
# Requirement already satisfied: stevedore>=3.0.0 in /opt/conda/lib/python3.9/site-packages (from qiskit-terra==0.21.1->qiskit~=0.37.0->pytket-qiskit) (4.0.0)
# Requirement already satisfied: retworkx>=0.11.0 in /opt/conda/lib/python3.9/site-packages (from qiskit-terra==0.21.1->qiskit~=0.37.0->pytket-qiskit) (0.11.0)
# Requirement already satisfied: symengine>=0.9 in /opt/conda/lib/python3.9/site-packages (from qiskit-terra==0.21.1->qiskit~=0.37.0->pytket-qiskit) (0.9.2)
# Requirement already satisfied: ply>=3.10 in /opt/conda/lib/python3.9/site-packages (from qiskit-terra==0.21.1->qiskit~=0.37.0->pytket-qiskit) (3.11)
# Requirement already satisfied: dill>=0.3 in /opt/conda/lib/python3.9/site-packages (from qiskit-terra==0.21.1->qiskit~=0.37.0->pytket-qiskit) (0.3.5.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.9/site-packages (from jinja2~=3.0->pytket~=1.5->pytket-qiskit) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.9/site-packages (from sympy~=1.6->pytket~=1.5->pytket-qiskit) (1.2.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.9/site-packages (from python-dateutil>=2.8.0->qiskit-ibmq-provider==0.19.2->qiskit~=0.37.0->pytket-qiskit) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.9/site-packages (from requests>=2.19->qiskit-ibmq-provider==0.19.2->qiskit~=0.37.0->pytket-qiskit) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/conda/lib/python3.9/site-packages (from requests>=2.19->qiskit-ibmq-provider==0.19.2->qiskit~=0.37.0->pytket-qiskit) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.9/site-packages (from requests>=2.19->qiskit-ibmq-provider==0.19.2->qiskit~=0.37.0->pytket-qiskit) (3.3)
# Requirement already satisfied: cryptography>=1.3 in /opt/conda/lib/python3.9/site-packages (from requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.19.2->qiskit~=0.37.0->pytket-qiskit) (36.0.1)
# Requirement already satisfied: ntlm-auth>=1.0.2 in /opt/conda/lib/python3.9/site-packages (from requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.19.2->qiskit~=0.37.0->pytket-qiskit) (1.5.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /opt/conda/lib/python3.9/site-packages (from stevedore>=3.0.0->qiskit-terra==0.21.1->qiskit~=0.37.0->pytket-qiskit) (5.10.0)
# Requirement already satisfied: cffi>=1.12 in /opt/conda/lib/python3.9/site-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.19.2->qiskit~=0.37.0->pytket-qiskit) (1.15.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.19.2->qiskit~=0.37.0->pytket-qiskit) (2.21)
#
# [notice] A new release of pip available: 22.1.2 -> 22.2.2
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ### Parameterise

# %%
from pytket.extensions.qiskit import AerBackend
from lambeq import TketModel

all_circuits = train_circuits+dev_circuits+test_circuits

backend = AerBackend()
backend_config = {
    'backend': backend,
    'compilation': backend.default_compilation_pass(2),
    'shots':8192 
}
model = TketModel.from_diagrams(all_circuits, backend_config=backend_config)

# %% [markdown]
# ### Define evaluation metric

# %%
loss = lambda y_hat, y: -np.sum(y * np.log(y_hat)) / len(y)  # binary cross-entropy loss
acc = lambda y_hat, y: np.sum(np.round(y_hat) == y) / len(y) / 2  # half due to double-counting

# %% [markdown]
# ### Initialize trainer

# %%
from lambeq import QuantumTrainer, SPSAOptimizer

trainer = QuantumTrainer(
    model,
    loss_function=loss,
    epochs=EPOCHS,
    optimizer=SPSAOptimizer,
    optim_hyperparams={'a': 0.05, 'c': 0.06, 'A':0.01*EPOCHS},
    evaluate_functions={'acc': acc},
    evaluate_on_train=True,
    verbose = 'text',
    seed=0
)

# %%
from lambeq import Dataset

train_dataset = Dataset(
            train_circuits,
            train_labels,
            batch_size=BATCH_SIZE)

val_dataset = Dataset(dev_circuits, dev_labels, shuffle=False)

# %% [markdown]
# ### Train

# %%
trainer.fit(train_dataset, val_dataset, logging_step=2)
# Out:
# Epoch 1:  train/loss: 3.0310   valid/loss: 1.9455   train/acc: 0.5250   valid/acc: 0.5000
# Epoch 2:  train/loss: 3.1739   valid/loss: 0.4504   train/acc: 0.4938   valid/acc: 0.7000
# Epoch 4:  train/loss: 2.8877   valid/loss: 3.3660   train/acc: 0.5500   valid/acc: 0.4500
# Epoch 6:  train/loss: 2.4876   valid/loss: 4.8485   train/acc: 0.4750   valid/acc: 0.5000
#
# Training completed!

# %% [markdown]
# ### Show results

# %%
import matplotlib.pyplot as plt

fig, ((ax_tl, ax_tr), (ax_bl, ax_br)) = plt.subplots(2, 2, sharex=True, sharey='row', figsize=(10, 6))
ax_tl.set_title('Training set')
ax_tr.set_title('Development set')
ax_bl.set_xlabel('Iterations')
ax_br.set_xlabel('Iterations')
ax_bl.set_ylabel('Accuracy')
ax_tl.set_ylabel('Loss')

colours = iter(plt.rcParams['axes.prop_cycle'].by_key()['color'])
ax_tl.plot(trainer.train_epoch_costs, color=next(colours))
ax_bl.plot(trainer.train_results['acc'], color=next(colours))
ax_tr.plot(trainer.val_costs, color=next(colours))
ax_br.plot(trainer.val_results['acc'], color=next(colours))

test_acc = acc(model(test_circuits), test_labels)
print('Test accuracy:', test_acc)
# Out:
# Test accuracy: 0.5
